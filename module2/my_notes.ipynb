# %%
print('Hello Jupyter Notebook!')
# Out:
# Hello Jupyter Notebook!

# %% [markdown]
# # Jupyter Notes
#
# Jupyter Notebook uses the .ipynb extension
#
# # Jupyter Shortcuts:
# - Ctrl + Enter: Runs and opens `new` cell
# - Shift + Enter: Runs `current` cell
# - Esc then y: Makes cell `code` mode
# - Esc then m: Makes cell `Markdown` mode

# %% [markdown]
# ## Bash/Terminal Commands
# Prefix them with `!`

# %%
# !conda list
# Out:
# # packages in environment at C:\Users\luksh\anaconda3:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2024.06             py312_mkl_2
# abseil-cpp                20211102.0           hd77b12b_0
# aiobotocore               2.12.3          py312haa95532_0
# aiohttp                   3.9.5           py312h2bbff1b_0
# aioitertools              0.7.1              pyhd3eb1b0_0
# aiosignal                 1.2.0              pyhd3eb1b0_0
# alabaster                 0.7.16          py312haa95532_0
# altair                    5.0.1           py312haa95532_0
# anaconda-anon-usage       0.4.4           py312hfc23b7f_100
# anaconda-catalogs         0.2.0           py312haa95532_1
# anaconda-client           1.12.3          py312haa95532_0
# anaconda-cloud-auth       0.5.1           py312haa95532_0
# anaconda-navigator        2.6.0           py312haa95532_0
# anaconda-project          0.11.1          py312haa95532_0
# ...

# %% [markdown]
# ## Magic Commands
# Prefix them with `%`.
#
# To get the list of magic commands use: `%lsmagic`

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# Run present working directory
# %pwd
# Out:
# 'e:\\WSU Classes\\CS 4580 Fall 2024\\my-notes-lukshsahitia\\module2'

# %% [markdown]
# One of the most common magic commands is the `%matplotlib inline` command. This command will enable plots to be displayed directly inside the notebook.

# %%
# %matplotlib inline

# %%
"""Simple demo of Scatter Plot"""
import numpy as np
import matplotlib.pyplot as plt

n = 50
x = np.random.rand(n)
y = np.random.rand(n)
colors = np.random.rand(n)

#Calculate area
area = np.pi * (15 * np.random.rand(n)) ** 2 # 0 to 15 point radius

# Plot Data
plt.scatter(x, y, s = area, c = colors, alpha = 0.5)
plt.show()

# %% [markdown]
# ## HTML
# Magic command to render the cell as `HTML`

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/f-hG-PiQz30?si=gZs_k60l9GxnKKgN" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/f-hG-PiQz30?si=gZs_k60l9GxnKKgN" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# # Conda
#
# Create and manage your virtual environments.
#
# To create virtual env. with a specific `python` version.
#
# ```bash
# conda create -n CS4580 python=3.10
# ```

# %% [markdown]
# To activate your environment run:
#
# ```bash
# conda activate CS4580
# # or
# activate CS4580
# ```

# %% [markdown]
# Get the list of current packages installed:
#
# ```bash
# conda env list
# ```

# %% [markdown]
# # Numpy
#
# ## Feature
# - High Performance
# - Vectorization
# - Broadcasting
# - Interoperability

# %% [markdown]
# ### Comparison with other alternatives
#
# #### Python List vs Numpy Arrays
# - Elements of different types `vs` the same type
# - Variable size nesting is possible `vs` the same size
# - No operations at the list level `vs` operations allowed at the array level
# - Uses a lot of memory `vs` less memory
